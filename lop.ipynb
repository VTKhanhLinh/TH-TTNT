# %% [markdown]
# <a href="https://colab.research.google.com/github/VTKhanhLinh/TH-TTNT/blob/main/lop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Viết chương trình nhập vào 2 giá trị a, b và tính tổng, hiệu, tích thương của a và b.
a=int(input("Nhập a:"))
b=int(input("Nhập b:"))
Tong=a+b
Hieu=a-b
Tich=a*b
Thuong=a/b
print(f"Tong: {Tong}")
print(f"Hieu: {Hieu}")
print(f"Tich: {Tich}")
print(f"Thuong: {Thuong}")
# Out:
# Nhập a:5
# Nhập b:6
# Tong: 11
# Hieu: -1
# Tich: 30
# Thuong: 0.8333333333333334

# %%
#2.Lấy các ký tự từ chỉ số 2 đến chỉ số 4 (llo) của chuỗi “Hello World”.
s="Hello World"
ketqua=s[2:5]
print(ketqua)
# Out:
# llo

# %%
#3.Xóa khoảng trắng thừa ở đầu và cuối chuỗi “   Hello World  ”. Chuyển chuỗi sang dạng hoa và thường. Thay ký tự H thành ký tự J.
s=" Hello World "
s1=s.strip()
s2=s.lower()
s4=s.replace('h','j')
s3=s.upper()
s5=s.replace('H','J')
print("Xóa:",s1)
print("Chữ Thường:",s2)
print("Thay Chữ Thường:",s4)
print("Chữ Hoa:",s3)
print("Thay Chữ Hoa:",s5)
# Out:
# Xóa: Hello World
# Chữ Thường:  hello world
# Thay Chữ Thường:  Hello World
# Chữ Hoa:  HELLO WORLD
# Thay Chữ Hoa:  Jello World

# %%
#4.In ra “Hello World!” nếu a lớn hơn b.
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
if a>b: print("Hello World")
else: print("a<b")
# Out:
# Nhap a:6
# Nhap b:4
# Hello World

# %%
#5.In ra “Yes” nếu a bằng b, ngược lại in “No”.
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
if a==b: print("yes")
else :print("no")
# Out:
# Nhap a:3
# Nhap b:7
# no

# %%
#6.In 1 nếu a bằng b, in 2 nếu a > b, in 3 nếu ngược lại.
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
if a==b: print(1)
elif  a>b:print(2)
else  :print(3)
# Out:
# Nhap a:6
# Nhap b:9
# 3

# %%
#7.In ra “Hello World!” nếu a bằng b và b bằng d.
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
d=int(input("Nhap d:"))
if a==b and b==d: print("Hello World")
# Out:
# Nhap a:6
# Nhap b:6
# Nhap d:6
# Hello World

# %%
#8.In ra “Hello World!” nếu a bằng b hoặc c bằng d.
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
c=int(input("Nhap c:"))
d=int(input("Nhap d:"))
if a==b or c==d: print("Hello World")
# Out:
# Nhap a:2
# Nhap b:2
# Nhap c:5
# Nhap d:5
# Hello World

# %%
#9.Viết lại câu lệnh if … else sau lên cùng 1 dòng.
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
print("yes")if a>b else print("no")
# Out:
# Nhap a:5
# Nhap b:3
# yes

# %%
#Nhập vào 2 số a, b. Thực hiện câu lệnh và cho biết kết quả
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# Nhap a:6
# Nhap b:7
# B

# %%
#11.Tạo mảng số nguyên a với n phần tử và mảng b chỉ chứa các phần tử chẵn của a.
import random
n = int(input("Nhập n: "))
# tạo mảng a
, 14, 8, 20, 2, 8, 6, 18, 2, 12, 12, 8, 14, 20, 12, 20, 8, 16, 4, 14, 14, 8, 16, 16, 10, 14, 2, 20, 4, 20, 20, 4, 4, 16, 14, 12, 18, 14, 6, 14, 10, 8, 6, 20, 10, 6, 18, 14, 20, 4, 20, 8, 2, 4, 8, 18, 6, 20, 18, 20, 2, 18, 20, 14, 16, 4, 10, 16, 16, 2, 18, 18, 8, 20, 16, 12, 4, 10, 2, 4, 18, 12, 6, 2, 4, 12, 10, 8, 2, 12, 14, 18, 16, 6, 10, 8, 12, 12, 4, 12, 18, 8, 4, 14, 6, 18, 12, 16, 10, 4, 10, 20, 2, 16, 4, 4, 10, 6, 8, 8, 8, 16, 2, 4, 4, 16, 2, 6, 6, 16, 10, 6, 18, 8, 18, 14, 12, 8, 20, 14, 14, 2, 4, 8, 2, 2, 12, 2, 16, 4, 16, 18, 10, 18, 2, 8, 2, 8, 12, 4, 8, 6, 2, 12, 12, 10, 12, 8, 6, 4, 4, 6, 12, 12, 16, 8, 20, 8, 18, 10, 16, 20, 16, 14, 20, 10, 8, 2, 14, 2, 10, 16, 10, 2, 2, 20, 8, 16, 18, 14, 6, 4, 20, 18, 6, 8, 8, 2, 16, 16, 14, 4, 4, 10, 2, 12, 10, 14, 20, 12, 6, 16, 4, 2, 2, 18, 8, 14, 12, 12, 4, 6, 20, 6, 4, 2, 14, 18, 12, 12, 20, 18, 14, 18, 12, 12, 12, 10, 18, 6, 14, 16, 8, 12, 14, 12, 14, 2, 12, 20, 10, 10, 14, 8, 10, 18, 10, 6, 8, 2, 8, 4, 8, 20, 2, 10, 20, 18, 14, 16, 20, 6, 12, 16, 18, 8, 10, 20, 4, 18, 10, 20, 12, 12, ...

# %%
#12.Viết chương trình tính tổng các số từ 0 đến 999 mà là bội của 3 hoặc 5.
total_sum = 0
n = 999
for i in range(n):
 if i%3 == 0 or i%5 == 0:
  total_sum +=i
print(f"\n Tong tu 0 đến {n} la boi so cua 3 và 5 là:{total_sum}")
# Out:
#  Tong tu 0 đến 999 la boi so cua 3 và 5 là:232169

# %%
#13.Viết hàm trộn 2 mảng một chiều thành 1 mảng một chiều với mỗi phần tử của mảng mới là tổng của 2 phần tương ứng từ 2 mảng cho trước. Trong quá trình trộn 2 mảng nếu mảng nào còn phần tử thì các phần tử còn lại của mảng đó sẽ đưa vào mảng mới.
#Ví dụ:
#Mảng a: 3 9 1 4
#Mảng b: 2 7 4 3 2 8
#Mảng kết quả: 5 16 5 7 2 8 23.

a=[3,9,1,4]
b=[2,7,4,3,2,8]
c=[]
for i in range(max(len(a), len(b))):
        if i< len(a) and i< len(b):
          c.append(a[i] +b[i])
        elif i<len(a):
          c.append(a[i])
        else:
          c.append(b[i])
print(c)
# Out:
# [5, 16, 5, 7, 2, 8]

# %%
#13.Viết hàm trộn 2 mảng một chiều thành 1 mảng một chiều với mỗi phần tử của mảng mới là tổng của 2 phần tương ứng từ 2 mảng cho trước. Trong quá trình trộn 2 mảng nếu mảng nào còn phần tử thì các phần tử còn lại của mảng đó sẽ đưa vào mảng mới.
#Ví dụ:
#Mảng a: 3 9 1 4
#Mảng b: 2 7 4 3 2 8
#Mảng kết quả: 5 16 5 7 2 8.

a=[3,9,1,4]
b=[2,7,4,3,2,8]
c=[]
min= len(b) if len(a)> len(b) else len(a)
c=a if len(a)> len(b)  else b
for i in range(min):
  c[i]=a[i]+b[i]

print(c)
# Out:
# [5, 16, 5, 7, 2, 8]

# %%
#14.Cho mảng 2 chiều a có m dòng, n cột chứa số nguyên, viết các hàm sau:
#a.Tạo mảng a chứa các số nguyên ngẫu nhiên.

import random
def tao_mang(m,n):
 return[[random.randint(1,20) for _ in range(n)]for _ in range(m)]

def in_mang(a):
  for row in a:
    print(*row)

#b.Xuất các phần tử thuộc dòng k.
def Xuat_dong(a,k):
  print("Dòng",k,":",a[k])

#c.Xuất các phần tử thuộc cột k.
def Xuat_cot(a,k):
  print("Cột",k,":", end=" ")
  for row in a:
     print(row[k], end=" ")
  print()


#d.Tìm dòng có tổng lớn nhất 45.
def Dong_co_tong_lon_nhat_duoi_45(a):
    max_sum = -1
    index = -1

    for i in range(len(a)):
        s = sum(a[i])
        if s < 45 and s > max_sum:
            max_sum = s
            index = i

    if index == -1:
        return None
    return index, max_sum

#e.Tìm cột có tích nhỏ nhất.
def Cot_tich_nho_nhat(a):
    num_rows = len(a)
    num_cols = len(a[0])
    min_product = float('inf')
    min_product_col_index = -1
    for j in range(num_cols): # Iterate through columns
        product = 1
        for i in range(num_rows): # Iterate through rows
            product *= a[i][j]
        if product < min_product:
            min_product = product
            min_product_col_index = j
    return min_product_col_index, min_product

#f.Xuất ra các phần tử thuộc dòng chẵn và cột lẻ trong a.
def Xuat_dong_chan_cot_le(a):
    result_elements = []
    for i in range(0, len(a), 2):
        for j in range(1, len(a[0]), 2):
            result_elements.append(str(a[i][j]))
    return " ".join(result_elements)

#g.Tính trung bình cộng các phần tử chẵn thuộc dòng lẻ của a.
def TBC_chan_dong_le(a):
    tong = 0
    dem = 0

    for i in range(len(a)): # Iterate through rows
        if i % 2 == 0:  # dòng lẻ (nếu tính từ 1, index 0,2,4... là dòng 1,3,5...)
            for j in range(len(a[i])):
                if a[i][j] % 2 == 0:
                    tong += a[i][j]
                    dem += 1

    if dem == 0:
        return 0
    return tong / dem

#h.Tính trung bình cộng các phần tử thuộc biên.
def TBC_bien(a):
    m, n = len(a), len(a[0])
    tong = dem = 0
    for i in range(m):
        for j in range(n):
            if i == 0 or i == m-1 or j == 0 or j == n-1:
                tong += a[i][j]
                dem += 1
    return tong/dem if dem else 0

#i.Tính trung bình tích các phần tử không thuộc biên.
def TBC_khong_bien(a):
    m, n = len(a), len(a[0])
    tich = 1
    dem = 0

    for i in range(1, m-1):
        for j in range(1, n-1):
            tich *= a[i][j]
            dem += 1

    return tich/dem if dem else 0


    # =====  TEST =====

m=int(input("Nhập m:"))
n=int(input("Nhập n:"))

a=tao_mang(m,n)
print("Mảng:")

in_mang(a)
k = int(input("Nhập k:"))

Xuat_dong(a, k)
Xuat_cot(a, k)
kq = Dong_co_tong_lon_nhat_duoi_45(a)

if kq is not None:
    print("Dòng:", kq[0], "tổng:", kq[1])
else:
    print("Không có dòng nào có tổng < 45")
print("Dòng có tổng <45 lớn nhất:",Dong_co_tong_lon_nhat_duoi_45(a))
print("Cột có tích nhỏ nhất:", Cot_tich_nho_nhat(a))
print("Phần tử dòng chẵn cột lẻ:", Xuat_dong_chan_cot_le(a))
print("TBC chẵn dòng lẻ:", TBC_chan_dong_le(a))
print("TBC biên:", TBC_bien(a))
print("TBC tích không biên:", TBC_khong_bien(a))
# Out:
# Nhập m:5
# Nhập n:4
# Mảng:
# 1 2 19 17
# 2 18 16 9
# 1 12 5 20
# 20 4 8 15
# 3 9 12 7
# Nhập k:2
# Dòng 2 : [1, 12, 5, 20]
# Cột 2 : 19 16 5 8 12
# Dòng: 0 tổng: 39
# Dòng có tổng <45 lớn nhất: (0, 39)
# Cột có tích nhỏ nhất: (0, 120)
# Phần tử dòng chẵn cột lẻ: 2 17 12 20 9 7
# TBC chẵn dòng lẻ: 11.5
# TBC biên: 9.785714285714286
# TBC tích không biên: 92160.0

# %%
#15.Một sinh viên gồm các thông tin sau:
#Mã sinh viên là chuỗi có 10 ký tự
#Tên là chuỗi tối đa 20 ký tự
#Năm sinh là một số nguyên
#Điểm trung bình là một số thực a.

#a.Xây dựng cấu trúc SINHVIEN mô tả một sinh viên
class SinhVien:
  def __init__(self, msv, ten, namsinh, diembb):
        self.msv = msv
        self.ten = ten
        self.namsinh = namsinh
        self.dtb = diembb

#b.Cho một mảng có n sinh viên.
def nhap_ds_sinh_vien(n):
    ds = []
    for i in range(n):
        print(f"\nNhập thông tin sinh viên thứ {i+1}:")
        while True:
            ma = input("Nhập mã sinh viên ( 10 ký tự): ")
            if len(ma) == 10:
                break
            else:
                print("Mã sinh viên không được vượt quá 10 ký tự. Vui lòng nhập lại.")
        while True:
            ten = input("Nhập tên sinh viên (tối đa 20 ký tự): ")
            if len(ten) <= 20:
                break
            else:
                print("Tên sinh viên không được vượt quá 20 ký tự. Vui lòng nhập lại.")
        while True:
            try:
                nam = int(input("Nhập năm sinh: "))
                break
            except ValueError:
                print("Năm sinh phải là một số nguyên. Vui lòng nhập lại.")
        while True:
            try:
                dtb = float(input("Nhập điểm trung bình: "))
                break
            except ValueError:
                print("Điểm trung bình phải là một số thực. Vui lòng nhập lại.")
        ds.append(SinhVien(ma, ten, nam, dtb))
    return ds

#c.Viết hàm cho biết có bao sinh viên đủ điều kiện lên lớp, biết rằng sinh viên đủ điều kiện lên lớp khi điểm trung bình lớn hơn hoặc bằng 5.
def dem_len_lop(ds):
    return sum(1 for sv in ds if sv.dtb >= 5)

#d.Xuất các sinh viên đủ 20 tuổi.
def sv_20_tuoi(ds):
    nam_hien_tai = 2026 # Giả sử năm hiện tại là 2026
    found = False
    for sv in ds:
        if nam_hien_tai - sv.namsinh >= 20:
            print(sv.ten)
            found = True
    if not found:
        print("Không có sinh viên nào đủ 20 tuổi.")

#e.Đếm số sinh viên học hệ đại học, biết rằng sinh viên hệ DH có mã sinh viên chứa 2 ký tự DH ở vị trí 2,3 trong chuỗi. VD: 02DH0001.
def dem_he_DH(ds):
    return sum(1 for sv in ds if len(sv.msv) >= 4 and sv.msv[2:4] == "DH")

#f.Cho biết trong mảng có bao nhiêu sinh viên có tên «Lan»
def dem_ten_lan(ds):
    return sum(1 for sv in ds if  sv.ten.split()[-1]=="Lan")

#g.Cho biết trong mảng có bao nhiêu sinh viên có họ «Phan»
def dem_ho_phan(ds):
    return sum(1 for sv in ds if sv.ten.split()[0] == "Phan")

# =====  TEST =====
n = int(input("Nhập số lượng sinh viên: "))
ds_sinh_vien = nhap_ds_sinh_vien(n)

print("\n--- KẾT QUẢ --- ")
print(f"Số sinh viên đủ điều kiện lên lớp: {dem_len_lop(ds_sinh_vien)}")
print(f"Số sinh viên hệ Đại học: {dem_he_DH(ds_sinh_vien)}")
print(f"Số sinh viên có tên 'Lan': {dem_ten_lan(ds_sinh_vien)}")
print(f"Số sinh viên có họ 'Phan': {dem_ho_phan(ds_sinh_vien)}")
print("Sinh viên đủ 20 tuổi:")
sv_20_tuoi(ds_sinh_vien)
# Out:
# Nhập số lượng sinh viên: 5
#
# Nhập thông tin sinh viên thứ 1:
# Nhập mã sinh viên ( 10 ký tự): 1000000001
# Nhập tên sinh viên (tối đa 20 ký tự): Nguyễn Phan Lan
# Nhập năm sinh: 2007
# Nhập điểm trung bình: 4
#
# Nhập thông tin sinh viên thứ 2:
# Nhập mã sinh viên ( 10 ký tự): 1000000002
# Nhập tên sinh viên (tối đa 20 ký tự): Phan Nhật Lan
# Nhập năm sinh: 2000
# Nhập điểm trung bình: 7
#
# Nhập thông tin sinh viên thứ 3:
# Nhập mã sinh viên ( 10 ký tự): 10DH000003
# Nhập tên sinh viên (tối đa 20 ký tự): Nguyễn Lan
# Nhập năm sinh: 2007
# Nhập điểm trung bình: 4
#
# Nhập thông tin sinh viên thứ 4:
# Nhập mã sinh viên ( 10 ký tự): 10DH000006
# Nhập tên sinh viên (tối đa 20 ký tự): Phan Anh
# Nhập năm sinh: 2004
# Nhập điểm trung bình: 7
#
# Nhập thông tin sinh viên thứ 5:
# Nhập mã sinh viên ( 10 ký tự): 10DH000002
# Nhập tên sinh viên (tối đa 20 ký tự): Huỳnh Nhi
# Nhập năm sinh: 2008
# Nhập điểm trung bình: 4
#
# --- KẾT QUẢ ---
# Số sinh viên đủ điều kiện lên lớp: 2
# Số sinh viên hệ Đại học: 3
# Số sinh viên có tên 'Lan': 3
# Số sinh viên có họ 'Phan': 2
# Sinh viên đủ 20 tuổi:
# Phan Nhật Lan
# Phan Anh
