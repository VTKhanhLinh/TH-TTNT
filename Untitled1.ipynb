# %% [markdown]
# <a href="https://colab.research.google.com/github/VTKhanhLinh/TH-TTNT/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import copy
from heapq import heappush, heappop

n=3

rows=[ 1, 0, -1, 0]
cols=[ 0, -1, 0, 1]

class priorityQueue:
  def__init__(self):
    self.heap=[]

  def push(selt, key):
    heappush(selt.heap, key)

  def pop(selt):
    return heappop(selt.heap)

  def emty(self):
    if not self.heap:
      return True
    else:
      return False

class nodes:
  def__init__(self, parent, mats, empty_tile_pos, costs, level):
    self.parent = parent
    self.mats=mats
    self.emty_tile_posi=emty_title_posi
    self.costs=costs
    self.level=level

    def __lt__(self, nxt):
    return self.costs < nxt.costs

def calculateCosts(mats, final) -> int:
  count =0
  for i in range(n):
    for j in range(n):
      if ((mats[i][j]) and
         (mats[i][j] != final[i][j])):
        count += 1

  return count

# %%
#1.Viết hàm trộn 2 mảng một chiều thành 1 mảng một chiều với mỗi phần tử của mảng mới là min của 2 phần tương ứng từ 2 mảng cho trước. Trong quá trình trộn 2 mảng nếu mảng nào còn phần tử thì các phần tử còn lại của mảng đó sẽ đưa vào mảng mới.
#Ví dụ:
#Mảng a: 3 9 1 4
#Mảng b: 2 7 4 3 2 8
#Mảng kết quả: 2 7 1 3 2 8
def tron_min(a, b):
    c = []
    m, n = len(a), len(b)
    for i in range(min(m, n)):
        c.append(min(a[i], b[i]))

    if m > n:
        c.extend(a[n:])
    else:
        c.extend(b[m:])

    return c
a = [3,9,1,4]
b = [2,7,4,3,2,8]
print(tron_min(a,b))
# Out:
# [2, 7, 1, 3, 2, 8]
